# %%
import pandas as pd
data = pd.read_csv('mushroom.csv', names=['class','cap-shape','cap-surface','cap-color','bruises',
                     'odor','gill-attachment','gill-spacing','gill-size','gill-color','stalk-shape','stalk-root',
                     'stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring',
                     'stalk-color-below-ring','veil-type','veil-color','ring-number',' ring-type',
                     'spore-print-color','population','habitat'])
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-9885c48a9035> in <module>()
#       4                      'stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring',
#       5                      'stalk-color-below-ring','veil-type','veil-color','ring-number',' ring-type',
# ----> 6                      'spore-print-color','population','habitat'])
#       7 data
#
# ...

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6208d269f320> in <module>()
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %%
from sklearn import preprocessing

# %% [markdown]
# ### 문자 데이터를 숫자 데이터로 변환

# %%
le = preprocessing.LabelEncoder()
# le.fit_transform(data['cap-shape'])
for col in data.columns:
    data[col] = le.fit_transform(data[col])
data
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# 5         0          5            3          9        1     0
# 6         0          0            2          8        1     0
# 7         0          0            3          8        1     3
# 8         1          5            3          8        1     6
# 9         0          0            2          9        1     0
# 10        0          5            3          9        1     3
# 11        0          5            3          9        1     0
# 12        0          0            2          9        1     0
# 13        1          5            3          8        1     6
# ...

# %%
x = data.iloc[:, 1:23]
y = data.iloc[:, 0]

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
x_train.info() #6093
x_test.info() #2031
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6093 entries, 3915 to 2423
# Data columns (total 22 columns):
# cap-shape                   6093 non-null int64
# cap-surface                 6093 non-null int64
# cap-color                   6093 non-null int64
# bruises                     6093 non-null int64
# odor                        6093 non-null int64
# gill-attachment             6093 non-null int64
# gill-spacing                6093 non-null int64
# gill-size                   6093 non-null int64
# gill-color                  6093 non-null int64
# stalk-shape                 6093 non-null int64
# stalk-root                  6093 non-null int64
# stalk-surface-above-ring    6093 non-null int64
# stalk-surface-below-ring    6093 non-null int64
# stalk-color-above-ring      6093 non-null int64
# stalk-color-below-ring      6093 non-null int64
# veil-type                   6093 non-null int64
# veil-color                  6093 non-null int64
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state = 42) 
# test_size 테스트 데이터를 1/3으로 줄떄, random_state 랜덤 시드를 줄때

# %%
x_train.info() #5443
x_test.info() #2681
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5443 entries, 854 to 7240
# Data columns (total 22 columns):
# cap-shape                   5443 non-null int64
# cap-surface                 5443 non-null int64
# cap-color                   5443 non-null int64
# bruises                     5443 non-null int64
# odor                        5443 non-null int64
# gill-attachment             5443 non-null int64
# gill-spacing                5443 non-null int64
# gill-size                   5443 non-null int64
# gill-color                  5443 non-null int64
# stalk-shape                 5443 non-null int64
# stalk-root                  5443 non-null int64
# stalk-surface-above-ring    5443 non-null int64
# stalk-surface-below-ring    5443 non-null int64
# stalk-color-above-ring      5443 non-null int64
# stalk-color-below-ring      5443 non-null int64
# veil-type                   5443 non-null int64
# veil-color                  5443 non-null int64
# ...

# %% [markdown]
# ### 표준화

# %%
scaler = preprocessing.StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
x_train
# Out:
# array([[ 0.4015128 , -1.49726079, -0.20237191, ..., -0.67910869,
#          0.28429659,  2.04207882],
#        [ 1.02663699, -1.49726079,  1.75691359, ..., -1.09934387,
#          0.28429659, -0.28640867],
#        [-0.84873558,  0.95202507, -0.98608611, ...,  1.42206719,
#          0.28429659, -0.86853054],
#        ...,
#        [ 1.02663699, -1.49726079, -0.59422901, ..., -1.09934387,
#          1.07019114,  1.45995695],
#        [ 1.02663699,  0.95202507, -0.20237191, ..., -0.67910869,
#          1.07019114, -0.86853054],
#        [-0.22361139,  0.13559645, -0.98608611, ...,  1.42206719,
#          0.28429659,  1.45995695]])

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit(x_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_hat = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
score = accuracy_score(y_test, y_hat)
score
# Out:
# 1.0

# %% [markdown]
#     y = ax
#     벡터 : 수의 순서쌍(순서가 중요 ★)
#
#     PCA(Principal Component Analysis)
#     데이터 분산이 가장 크게 만드는 축
#     PCA: 고차원 data(이미지)에서 패턴을 찾는 도구
#
#     행렬: 두 변수간 관계
#
#     공분산 행렬: 고유벡터와 고유값을 찾는 것은 데이터의 주성분 찾는것과 동일
#     고유벡터: 행렬이 어느 방향으로 힘을 주는지 <=> 데이터가 어느 방향으로 분산이 가장 큰지를 구하는 것

# %%
# Eating, exercise habbit and their body shape
df = pd.DataFrame(columns=['calory', 'breakfast', 'lunch', 'dinner', 'exercise', 'body_shape'])
df.loc[0] = [1200, 1, 0, 0, 2, 'Skinny']
df.loc[1] = [2800, 1, 1, 1, 1, 'Normal']
df.loc[2] = [3500, 2, 2, 1, 0, 'Fat']
df.loc[3] = [1400, 0, 1, 0, 3, 'Skinny']
df.loc[4] = [5000, 2, 2, 2, 0, 'Fat']
df.loc[5] = [1300, 0, 0, 1, 2, 'Skinny']
df.loc[6] = [3000, 1, 0, 1, 1, 'Normal']
df.loc[7] = [4000, 2, 2, 2, 0, 'Fat']
df.loc[8] = [2600, 0, 2, 0, 0, 'Normal']
df.loc[9] = [3000, 1, 2, 1, 1, 'Fat']

# %%
df
# Out:
#   calory breakfast lunch dinner exercise body_shape
# 0   1200         1     0      0        2     Skinny
# 1   2800         1     1      1        1     Normal
# 2   3500         2     2      1        0        Fat
# 3   1400         0     1      0        3     Skinny
# 4   5000         2     2      2        0        Fat
# 5   1300         0     0      1        2     Skinny
# 6   3000         1     0      1        1     Normal
# 7   4000         2     2      2        0        Fat
# 8   2600         0     2      0        0     Normal
# 9   3000         1     2      1        1        Fat

# %%
x = df.iloc[:, 0:5]
x
# Out:
#   calory breakfast lunch dinner exercise
# 0   1200         1     0      0        2
# 1   2800         1     1      1        1
# 2   3500         2     2      1        0
# 3   1400         0     1      0        3
# 4   5000         2     2      2        0
# 5   1300         0     0      1        2
# 6   3000         1     0      1        1
# 7   4000         2     2      2        0
# 8   2600         0     2      0        0
# 9   3000         1     2      1        1

# %%
y = df[['body_shape']]
y
# Out:
#   body_shape
# 0     Skinny
# 1     Normal
# 2        Fat
# 3     Skinny
# 4        Fat
# 5     Skinny
# 6     Normal
# 7        Fat
# 8     Normal
# 9        Fat

# %%
# x데이터 표준화
x
# Out:
#   calory breakfast lunch dinner exercise
# 0   1200         1     0      0        2
# 1   2800         1     1      1        1
# 2   3500         2     2      1        0
# 3   1400         0     1      0        3
# 4   5000         2     2      2        0
# 5   1300         0     0      1        2
# 6   3000         1     0      1        1
# 7   4000         2     2      2        0
# 8   2600         0     2      0        0
# 9   3000         1     2      1        1

# %%
from sklearn.preprocessing import StandardScaler

# %%
x_std=StandardScaler().fit_transform(x)

# %%
x_std
# Out:
# array([[-1.35205803,  0.        , -1.3764944 , -1.28571429,  1.        ],
#        [ 0.01711466,  0.        , -0.22941573,  0.14285714,  0.        ],
#        [ 0.61612771,  1.29099445,  0.91766294,  0.14285714, -1.        ],
#        [-1.18091145, -1.29099445, -0.22941573, -1.28571429,  2.        ],
#        [ 1.89972711,  1.29099445,  0.91766294,  1.57142857, -1.        ],
#        [-1.26648474, -1.29099445, -1.3764944 ,  0.14285714,  1.        ],
#        [ 0.18826125,  0.        , -1.3764944 ,  0.14285714,  0.        ],
#        [ 1.04399418,  1.29099445,  0.91766294,  1.57142857, -1.        ],
#        [-0.15403193, -1.29099445,  0.91766294, -1.28571429, -1.        ],
#        [ 0.18826125,  0.        ,  0.91766294,  0.14285714,  0.        ]])

# %%
features = x_std.T # (5, 10)각 행은 feature, 각 열은 인스턴스들의 값
# 공분산을 구하기위해 각 변수를 행으로 오도록 transpose를 함(전치행렬)

# %%
cov_metrics = np.cov(features)
cov_metrics
# calory	breakfast	lunch	dinner	exercise
# Out:
# array([[ 1.11111111,  0.88379717,  0.76782385,  0.89376551, -0.93179808],
#        [ 0.88379717,  1.11111111,  0.49362406,  0.81967902, -0.71721914],
#        [ 0.76782385,  0.49362406,  1.11111111,  0.40056715, -0.76471911],
#        [ 0.89376551,  0.81967902,  0.40056715,  1.11111111, -0.63492063],
#        [-0.93179808, -0.71721914, -0.76471911, -0.63492063,  1.11111111]])

# %%
# 공분산 행렬 -> 아이겐 벡터 추출 & 아이겐 벨류 계산
eig_vals, eig_vecs = np.linalg.eig(cov_metrics)
# (array([4.0657343 , 0.8387565 , 0.07629538, 0.27758568, 0.2971837 ]),  아이겐 벨류
#  array([[ 0.508005  ,  0.0169937 , -0.84711404,  0.11637853,  0.10244985], 아이겐 벡터
#         [ 0.44660335,  0.36890361,  0.12808055, -0.63112016, -0.49973822],
#         [ 0.38377913, -0.70804084,  0.20681005, -0.40305226,  0.38232213],
#         [ 0.42845209,  0.53194699,  0.3694462 ,  0.22228235,  0.58954327],
#         [-0.46002038,  0.2816592 , -0.29450345, -0.61341895,  0.49601841]]))

# %%
eig_vals
# Out:
# array([4.0657343 , 0.8387565 , 0.07629538, 0.27758568, 0.2971837 ])

# %%
eig_vals[0]/sum(eig_vals) # 5차원데이터를 1차원으로 축소하면 73% 정보가 반영 <=> 27%는 정보손실됨
# Out:
# 0.7318321731427544

# %%
(eig_vals[0]+eig_vals[1])/sum(eig_vals) # 5차원데이터를 2차원으로 축소하면 88% 정보가 반영 <=> 12%는 정보손실됨
# Out:
# 0.8828083437099052

# %%
eig_vecs
# Out:
# array([[ 0.508005  ,  0.0169937 , -0.84711404,  0.11637853,  0.10244985],
#        [ 0.44660335,  0.36890361,  0.12808055, -0.63112016, -0.49973822],
#        [ 0.38377913, -0.70804084,  0.20681005, -0.40305226,  0.38232213],
#        [ 0.42845209,  0.53194699,  0.3694462 ,  0.22228235,  0.58954327],
#        [-0.46002038,  0.2816592 , -0.29450345, -0.61341895,  0.49601841]])

# %%
eig_vecs.T[0]
# Out:
# array([ 0.508005  ,  0.44660335,  0.38377913,  0.42845209, -0.46002038])

# %%
projected_x = x_std.dot(eig_vecs.T[0])
projected_x
# Out:
# array([-2.22600943, -0.0181432 ,  1.76296611, -2.73542407,  3.02711544,
#        -2.14702579, -0.37142473,  2.59239883, -0.39347815,  0.50902498])

# %%
import numpy as np
res = pd.DataFrame(projected_x, columns = ['PC1'])
res['y'] = 0
res['label'] = y

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.lmplot('PC1', 'y', data = res, hue = 'label', fit_reg=False)

# %%
mr = pd.read_csv('mushroom.csv', names=['class','cap-shape','cap-surface','cap-color','bruises',
                     'odor','gill-attachment','gill-spacing','gill-size','gill-color','stalk-shape','stalk-root',
                     'stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring',
                     'stalk-color-below-ring','veil-type','veil-color','ring-number',' ring-type',
                     'spore-print-color','population','habitat'])
mr
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# 5        e         x           y         y       t    a               f
# 6        e         b           s         w       t    a               f
# 7        e         b           y         w       t    l               f
# 8        p         x           y         w       t    p               f
# 9        e         b           s         y       t    a               f
# 10       e         x           y         y       t    l               f
# 11       e         x           y         y       t    a               f
# ...

# %%
data=[]
label =[]
for row_index, row in mr.iterrows():
    label.append(row.ix[0])
    row_data = []
    for v in row.ix[1:]:
        row_data.append(ord(v))
    data.append(row_data)
print(data)
# Out:
# C:\Users\B-1\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
# C:\Users\B-1\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# ...

# %%
traind, testd, trainl, testl = train_test_split(data, label)

# %% [markdown]
# #### 데이터 학습

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier()
clf.fit(traind, trainl)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
predict = clf.predict(testd)

# %%
score = accuracy_score(testl, predict)

# %%
print('정답', score)
# Out:
# 정답 1.0

# %%
from sklearn import metrics
clr = metrics.classification_report(testl, predict)
print('리포트', clr)
# Out:
# 리포트              precision    recall  f1-score   support
#
#           e       1.00      1.00      1.00      1046
#           p       1.00      1.00      1.00       985
#
# avg / total       1.00      1.00      1.00      2031
